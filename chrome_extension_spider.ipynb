# %%
import os
import sys
import time
import json
import requests
import yaml

import numpy as np
import pandas as pd
from tqdm import tqdm

from urllib.parse import urlparse, urlunparse
from sqlalchemy import create_engine

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

def start_headless_browser():
    options = Options()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument('--disable-extensions')
    options.add_argument('--disable-infobars')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-popup-blocking')
    options.add_argument('--disable-default-apps')
    options.add_argument('--disable-translate')
    options.add_argument('--disable-web-security')
    options.add_argument('--disable-features=IsolateOrigins,site-per-process')
    options.add_argument('--blink-settings=imagesEnabled=false')
    options.add_argument('--disable-javascript')
    
    browser = webdriver.Chrome(options=options)

    browser.execute_cdp_cmd('Network.setUserAgentOverride', {
    "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
        })
    #browser.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
    #  "source": """
    #    Object.defineProperty(navigator, 'webdriver', {
    #      get: () => undefined
    #    })
    #  """
    #})
    #browser.execute_cdp_cmd("Network.enable", {})
    #browser.execute_cdp_cmd("Network.setExtraHTTPHeaders", {"headers": {"User-Agent": "browser1"}})
    return browser

def query_comments(url):
    browser.get(url)
    for element in browser.find_elements(By.CSS_SELECTOR,"div"):
        if element.get_attribute("role") == "combobox":
            language_box = element
    language_box.find_elements(By.CSS_SELECTOR,"div")[0].click()
    language_box.click()
    time.sleep(0.5)
    for element in browser.find_elements(By.CSS_SELECTOR,"ul"):
        if (element.get_attribute("aria-label") == "语言")|(element.get_attribute("aria-label") == "Language"):
            language_box = element
    language_box.find_elements(By.CSS_SELECTOR,"li")[-1].click()

def next_page_comments():
    span_elements = browser.find_elements(By.CSS_SELECTOR,"span")
    span_elements.reverse()
    for span in span_elements:
        if (span.text == "加载更多")|(span.text == "Load more"):
            next_page = span
            break
    next_page.click()

def parse_comments(path=None):
    if path != None:
        with open(f"{path}","r",encoding="utf-8") as file:
            response = file.read()
    else:
        response = browser.page_source
    
    response = BeautifulSoup(response)

    # 从浏览器获取标题和评论css id
    class_list = [section.get_attribute("class") for section in browser.find_elements(By.CSS_SELECTOR,"section")]
    header_class,comment_class = class_list[0],class_list[-1]
    info = browser.find_element(By.CSS_SELECTOR,f"section.{header_class}").text.split("\n")
    
    results = []
    
    response_list = response.find_all("section",attrs={"class":f"{comment_class}"})
    length = len(response_list)
    
    for i in tqdm(range(length)):
        try:
            rate = response_list[i].find("div",attrs={"class":"B1UG8d"}).attrs["title"]
            user = response_list[i].find("span").text
            comment = response_list[i].find("p").text
            comment_time = response_list[i].find("span",attrs={"class":"ydlbEf"}).text
            helpful_num = response_list[i].find("span",attrs={"class":"ZRk0Tb"}).text
            result = {"rate":rate, "user":user, "comment":comment, "comment_time":comment_time, "helpful":helpful_num}
            results.append(result)
        except:
            continue
    
    comment_output = pd.DataFrame(results)
    try:
        comment_output["comment_time"] = pd.to_datetime(comment_output["comment_time"],format="%Y年%m月%d日")
    except:
        try:
            comment_output["comment_time"] = pd.to_datetime(comment_output["comment_time"], format='%b %d, %Y')
        except:
            pass
    return comment_output

def check_browser():
    time_now = pd.Timestamp.now().strftime(format="%m-%d-%H-%M")
    browser.save_screenshot(f"log/excptions/{time_now}.png")
    with open(f"log/excptions/{time_now}.html","w",encoding="utf-8") as file:
        file.write(browser.page_source)

def fetchUrl(url,cookies=None):
    """
    Fetches content from a URL using a GET request with custom User-Agent and cookies.
    """
    # Ensure headers and cookies are dictionaries, if not provided, initialize as empty dicts
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    headers = {"User-Agent": user_agent}
    if cookies is None:
        cookies = {}
    
    # Perform the GET request
    response = requests.get(url, headers=headers, cookies=cookies)
    
    return response
# Out:
# C:\Users\moma.DESKTOP-QTGQJ1H\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
browser = start_headless_browser()
check_browser()

with open("config/coupon_chrome_extensions_url.yaml","r") as file:
    tools = yaml.safe_load(file.read())
for name,url in tools.items():
    if os.path.exists(f"data/chrome_extension/{name}.csv"):
        continue
    print(name,url)
    query_comments(url)
    for i in tqdm(range(150)):
        try:
            next_page_comments()
        except:
            try:
                next_page_comments()
            except:
                check_browser()
                break
        time.sleep(1.5)
        if i%200 == 0:
            with open(f"data/chrome_extension/{name}_{i}.html","w",encoding="utf-8") as file:
                file.write(browser.page_source)
    output_data = parse_comments(path=None) 
    output_data.to_csv(f"data/chrome_extension/{name}.csv")

parse_comments()
# Out:
# couponbirds https://chromewebstore.google.com/detail/couponbirds-smartcoupon-c/pnedebpjhiaidlbbhmogocmffpdolnek/reviews?hl=en
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [04:34<00:00,  1.83s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 1510/1510 [00:00<00:00, 6848.03it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 1510/1510 [00:00<00:00, 5540.98it/s]
#          rate                 user  \
# 0     4 stars           Ben George
# 1     4 stars         Heather West
# 2     5 stars         Jordan Banks
# 3     5 stars           CharlieGTR
# 4     5 stars    Rosshondra Irving
# ...       ...                  ...
# 1505  5 stars  Rachel (RP Imagery)
# 1506  5 stars       Perry Carrison
# 1507  5 stars                 Alex
# 1508  5 stars        Igor Lebediev
# 1509  5 stars         Aluisio Melo
#
#                                                 comment comment_time helpful
# 0     Always making an effort to save and often succ...   2024-04-10
# 1     This has worked once for me, but I'm saving mo...   2024-04-10
# 2                                                  good   2024-04-10
# 3                                            VERY GOOD!   2024-04-10
# 4                                        almost 100 off   2024-04-10
# ...                                                 ...          ...     ...
# 1505                   Just saved 100 bucks! thank you!   2024-01-18
# 1506  The easiest $21 I ever saved. Go for it! Coupo...   2024-01-18
# 1507                                                      2024-01-18
# 1508                                                      2024-01-18
# 1509                     Exelente, economizei 40 reais.   2024-01-18
#
# [1510 rows x 5 columns]

# %%
output_data = parse_comments()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 54/54 [00:00<?, ?it/s]

# %%
output_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def fetchUrl(url,cookies=None):
    """
    Fetches content from a URL using a GET request with custom User-Agent and cookies.
    """
    # Ensure headers and cookies are dictionaries, if not provided, initialize as empty dicts
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    headers = {"User-Agent": user_agent}
    if cookies is None:
        cookies = {}
    
    # Perform the GET request
    response = requests.get(url, headers=headers, cookies=cookies)
    
    return response

def amazon_cookie_manage():
    """save cookie from https://moz.com/domain-analysis"""
    with open("config/amazon_cookie.json","r") as file:
        cookies = json.loads(file.read())
        cookies = cookies["cookies"]
        cookies_amazon = {cookie["name"]:cookie["value"] for cookie in cookies}
    return cookies_amazon

# %%
def parse_page(path):
    with open(f"{path}","r",encoding="utf-8") as file:
        response = file.read()
    response = BeautifulSoup(response)

    title = response.find("span",attrs={"id":"productTitle"}).text.strip()
    rate = response.find("span",attrs={"id":"acrPopover"}).span.a.span.text.strip()
    rate_number = response.find("span",attrs={"id":"acrCustomerReviewText"}).text.strip()
    sold_number = response.find("span",attrs={"id":"social-proofing-faceout-title-tk_bought"}).span.text.strip()
    description = response.find("div",attrs={"id":"feature-bullets"}).ul.text
    rate_dist = [tr.text for tr in response.select("#cm_cr_dp_d_rating_histogram")[0].find_all("tr")]
    ai_comment = response.select("#product-summary")[0].text
    keyword_comments = response.select("#cr-product-insights-cards > div:nth-child(2) > div.a-section.a-spacing-mini._cr-product-insights_style_sentiment-section__6zKPq > div ")[0].find_all("span")
    keyword_comments = [span.text for span in keyword_comments]
    nav = " ".join([li.text.strip() for li in response.select("#wayfinding-breadcrumbs_feature_div > ul > li")])
    user_reviews = response.find_all("div",attrs={"id":"cm-cr-dp-review-list"})[0].text

    product_info = {
        "title": title,
        "rate": rate,
        "rate_number": rate_number,
        "sold_number": sold_number,
        "description": description,
        "rate_dist": rate_dist,
        "ai_comment": ai_comment,
        "keyword_comments": keyword_comments,
        "nav": nav,
        "user_reviews":user_reviews
    }

    return product_info

# %%
output = []
url_list = os.listdir("data/amazon_html")
for url in tqdm(url_list):
    try:
        result = parse_page(f"data/amazon_html/{url}")
        output.append(result)
    except:
        continue
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 362/362 [01:40<00:00,  3.61it/s]

# %%
pd.DataFrame(output)
# Out:
#                                                  title rate      rate_number  \
# 0    Amazon Fire TV Stick, HD, sharp picture qualit...  4.7  462,719 ratings
# 1    Pure Instinct Roll-On - The Original Pheromone...  3.9   81,031 ratings
# 2    Quest 2 — Advanced All-In-One Virtual Reality ...  4.7   71,784 ratings
# 3    Google Pixel 6a - 5G Android Phone - Unlocked ...  4.3    4,762 ratings
# 4    WalkingPad Folding Treadmill, Ultra Slim Folda...  3.9      803 ratings
# ..                                                 ...  ...              ...
# 98   Amazon Basics High-Speed HDMI Cable For Televi...  4.7  533,087 ratings
# 99   Hero Cosmetics Mighty Patch™ Original Patch - ...  4.6  142,363 ratings
# 100  Nugenix Total-T, Free and Total Testosterone B...  4.1   15,820 ratings
# 101  URO Vaginal Probiotics for Women pH Balance wi...  4.3      340 ratings
# 102  Samyang Buldak Chicken Stir Fried Ramen Korean...  4.4    3,932 ratings
#
#                     sold_number  \
# 0     10K+ bought in past month
# 1     10K+ bought in past month
# 2     30K+ bought in past month
# 3     200+ bought in past month
# 4     500+ bought in past month
# ..                          ...
# 98    10K+ bought in past month
# 99   100K+ bought in past month
# 100   10K+ bought in past month
# 101  100K+ bought in past month
# 102    1K+ bought in past month
#
#                                            description  \
# 0      50% more powerful than the previous generati...
# 1      More than 20 years ago, Pure Instinct change...
# 2      Experience total immersion with 3D positiona...
# 3      Google Pixel 6a adapts to you; it’s super fa...
# 4      Ultra Slim Foldable Running Board For Easy S...
# ..                                                 ...
# 98     IN THE BOX: HDMI cable (A Male to A Male) fo...
# 99     🏆 The Original Award-Winning Acne Patch: Mig...
# 100    Scientifically formulated, our new-and-impro...
# 101    Promotes Vaginal Health: URO Probiotic for w...
# 102    1 x Buldak Original / 1 x Carbo / 1 x Cheese...
#
#                                              rate_dist  \
# 0    [5 star82%, 4 star11%, 3 star3%, 2 star1%, 1 s...
# 1    [5 star52%, 4 star13%, 3 star14%, 2 star8%, 1 ...
# 2    [5 star84%, 4 star9%, 3 star3%, 2 star1%, 1 st...
# 3    [5 star67%, 4 star15%, 3 star5%, 2 star4%, 1 s...
# 4    [5 star57%, 4 star16%, 3 star6%, 2 star6%, 1 s...
# ..                                                 ...
# 98   [5 star82%, 4 star12%, 3 star4%, 2 star1%, 1 s...
# 99   [5 star76%, 4 star12%, 3 star7%, 2 star2%, 1 s...
# 100  [5 star59%, 4 star15%, 3 star12%, 2 star5%, 1 ...
# 101  [5 star74%, 4 star8%, 3 star3%, 2 star3%, 1 st...
# 102  [5 star72%, 4 star13%, 3 star7%, 2 star3%, 1 s...
#
#                                             ai_comment  \
# 0    Customers sayCustomers like the performance an...
# 1    Customers sayCustomers like the portability of...
# 2    Customers sayCustomers like the ease of setup ...
# 3    Customers sayCustomers like the value of the c...
# 4    Customers sayCustomers like the ease of foldin...
# ..                                                 ...
# 98   Customers sayCustomers like the quality, value...
# 99   Customers sayCustomers like the quality, visib...
# 100  Customers sayCustomers like the energy, qualit...
# 101  Customers sayCustomers like the vitamins, perf...
# 102  Customers sayCustomers like the quality of the...
#
#                                       keyword_comments  \
# 0                  [Performance, Ease of use, Quality]
# 1    [Appearance, Portability, Ease of application,...
# 2    [Quality, Entertainment value, Ease of setup, ...
# 3    [Value, Photos, Quality, Battery life, Chargin...
# 4    [Ease of folding, Performance, Ease of use, Qu...
# ..                                                 ...
# 98   [Performance, Quality, Value, Fit, Picture qua...
# 99   [Performance, Effect on skin, Quality, Sensiti...
# 100  [Energy, Quality, Effects, Performance, Sleep ...
# 101  [Performance, Smell, Vitamins, Health benefits...
# 102  [Quality, Ease of making, Taste, Temperature, ...
#
#                                                    nav  \
# 0
# 1    Beauty & Personal Care › Fragrance › Men's › C...
# 2    Video Games › Virtual Reality › Standalone Har...
# 3              Cell Phones & Accessories › Cell Phones
# 4    Sports & Outdoors › Exercise & Fitness › Cardi...
# ..                                                 ...
# 98   Electronics › Television & Video › Accessories...
# 99   Beauty & Personal Care › Skin Care › Face › Tr...
# 100  Health & Household › Diet & Sports Nutrition ›...
# 101  Health & Household › Health Care › Women's Hea...
# 102  Grocery & Gourmet Food › Pantry Staples › Soup...
#
#                                           user_reviews
# 0    CARLOS PINEDA5.0 out of 5 stars\nAwesome quali...
# 1    Natalia5.0 out of 5 stars\nWorks! Just not how...
# 2    Yaura5.0 out of 5 stars\nAmazing Overall\nRevi...
# 3    Nurse Bill5.0 out of 5 stars\nSolid as a rock\...
# 4    Amazon Customer5.0 out of 5 stars\nWalking whi...
# ..                                                 ...
# 98   carla5.0 out of 5 stars\nYear-Long Reliability...
# 99   Ana Maria5.0 out of 5 stars\nMaybe not the bes...
# 100  Odizie Ajike5.0 out of 5 stars\nUOUR PRODUCT\n...
# 101  A. Williams5.0 out of 5 stars\nI’ve noticed a ...
# 102  Gavin Whittington5.0 out of 5 stars\nTaste gre...
#
# [103 rows x 10 columns]

# %%
def sleep_time(base,random=1):
    random_time = base + np.random.randint(10000,99999)/(10**5)
    time.sleep(random_time)

# %%
pd.DataFrame(output).to_clipboard()

# %%
input_data = pd.read_csv("data/amazon_url_test.csv")
url_list = input_data["URL"].to_list()

# %%
result = fetchUrl("https://www.amazon.com/Wordle-Party-Players-Official-Inspired/dp/B0B5B9CP17",cookies=cookies)

# %%
i = 1975
for url in tqdm(url_list[1975:15000]):

    url = url+"?language=en_US"
    sleep_time(1)
    cookies = amazon_cookie_manage()
    response = fetchUrl(f"{url}",cookies=cookies)
    with open(f"data/amazon_html/amazon_{i}.html","w",encoding="utf-8") as file:
        file.write(response.text)
    sleep_time(6)
    i += 1
# Out:
#   1%|▉                                                                          | 166/13025 [32:07<41:28:40, 11.61s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 10
#       8 with open(f"data/amazon_html/amazon_{i}.html","w",encoding="utf-8") as file:
#       9     file.write(response.text)
# ---> 10 sleep_time(6)
#      11 i += 1
#
# Cell In[8], line 3, in sleep_time(base, random)
#       1 def sleep_time(base,random=1):
#       2     random_time = base + np.random.randint(10000,99999)/(10**5)
# ----> 3     time.sleep(random_time)
#
# KeyboardInterrupt:

# %%
import os
import sys
import time
import json
import requests
import yaml

import numpy as np
import pandas as pd
from tqdm import tqdm

from urllib.parse import urlparse, urlunparse
from sqlalchemy import create_engine

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

def start_headless_browser():
    options = Options()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument('--disable-extensions')
    options.add_argument('--disable-infobars')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-popup-blocking')
    options.add_argument('--disable-default-apps')
    options.add_argument('--disable-translate')
    options.add_argument('--disable-web-security')
    options.add_argument('--disable-features=IsolateOrigins,site-per-process')
    options.add_argument('--blink-settings=imagesEnabled=false')
    options.add_argument('--disable-javascript')
    
    browser = webdriver.Chrome(options=options)

    browser.execute_cdp_cmd('Network.setUserAgentOverride', {
    "userAgent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
        })
    #browser.execute_cdp_cmd("Page.addScriptToEvaluateOnNewDocument", {
    #  "source": """
    #    Object.defineProperty(navigator, 'webdriver', {
    #      get: () => undefined
    #    })
    #  """
    #})
    #browser.execute_cdp_cmd("Network.enable", {})
    #browser.execute_cdp_cmd("Network.setExtraHTTPHeaders", {"headers": {"User-Agent": "browser1"}})
    return browser

def query_comments(url):
    browser.get(url)
    for element in browser.find_elements(By.CSS_SELECTOR,"div"):
        if element.get_attribute("role") == "combobox":
            language_box = element
    language_box.find_elements(By.CSS_SELECTOR,"div")[0].click()
    language_box.click()
    time.sleep(0.5)
    for element in browser.find_elements(By.CSS_SELECTOR,"ul"):
        if (element.get_attribute("aria-label") == "语言")|(element.get_attribute("aria-label") == "Language"):
            language_box = element
    language_box.find_elements(By.CSS_SELECTOR,"li")[-1].click()

def next_page_comments():
    span_elements = browser.find_elements(By.CSS_SELECTOR,"span")
    span_elements.reverse()
    for span in span_elements:
        if (span.text == "加载更多")|(span.text == "Load more"):
            next_page = span
            break
    next_page.click()

def parse_comments(path=None):
    if path != None:
        with open(f"{path}","r",encoding="utf-8") as file:
            response = file.read()
    else:
        response = browser.page_source
    
    response = BeautifulSoup(response)

    # 从浏览器获取标题和评论css id
    class_list = [section.get_attribute("class") for section in browser.find_elements(By.CSS_SELECTOR,"section")]
    header_class,comment_class = class_list[0],class_list[-1]
    info = browser.find_element(By.CSS_SELECTOR,f"section.{header_class}").text.split("\n")
    
    results = []
    
    response_list = response.find_all("section",attrs={"class":f"{comment_class}"})
    length = len(response_list)
    
    for i in tqdm(range(length)):
        try:
            rate = response_list[i].find("div",attrs={"class":"B1UG8d"}).attrs["title"]
            user = response_list[i].find("span").text
            comment = response_list[i].find("p").text
            comment_time = response_list[i].find("span",attrs={"class":"ydlbEf"}).text
            helpful_num = response_list[i].find("span",attrs={"class":"ZRk0Tb"}).text
            result = {"rate":rate, "user":user, "comment":comment, "comment_time":comment_time, "helpful":helpful_num}
            results.append(result)
        except:
            continue
    
    comment_output = pd.DataFrame(results)
    try:
        comment_output["comment_time"] = pd.to_datetime(comment_output["comment_time"],format="%Y年%m月%d日")
    except:
        try:
            comment_output["comment_time"] = pd.to_datetime(comment_output["comment_time"], format='%b %d, %Y')
        except:
            pass
    return comment_output

def check_browser():
    time_now = pd.Timestamp.now().strftime(format="%m-%d-%H-%M")
    browser.save_screenshot(f"log/excptions/{time_now}.png")
    with open(f"log/excptions/{time_now}.html","w",encoding="utf-8") as file:
        file.write(browser.page_source)

# %%
browser = start_headless_browser()
check_browser()

with open("config/coupon_chrome_extensions_url.yaml","r") as file:
    tools = yaml.safe_load(file.read())
for name,url in tools.items():
    if os.path.exists(f"data/chrome_extension/{name}.csv"):
        continue
    print(name,url)
    query_comments(url)
    for i in tqdm(range(150)):
        try:
            next_page_comments()
        except:
            try:
                next_page_comments()
            except:
                check_browser()
                break
        time.sleep(1.5)
        if i%200 == 0:
            with open(f"data/chrome_extension/{name}_{i}.html","w",encoding="utf-8") as file:
                file.write(browser.page_source)
    output_data = parse_comments(path=None) 
    output_data.to_csv(f"data/chrome_extension/{name}.csv")

parse_comments()
# Out:
# couponbirds https://chromewebstore.google.com/detail/couponbirds-smartcoupon-c/pnedebpjhiaidlbbhmogocmffpdolnek/reviews?hl=en
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [04:34<00:00,  1.83s/it]
# 100%|████████████████████████████████████████████████████████████████████████████| 1510/1510 [00:00<00:00, 6848.03it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 1510/1510 [00:00<00:00, 5540.98it/s]
#          rate                 user  \
# 0     4 stars           Ben George
# 1     4 stars         Heather West
# 2     5 stars         Jordan Banks
# 3     5 stars           CharlieGTR
# 4     5 stars    Rosshondra Irving
# ...       ...                  ...
# 1505  5 stars  Rachel (RP Imagery)
# 1506  5 stars       Perry Carrison
# 1507  5 stars                 Alex
# 1508  5 stars        Igor Lebediev
# 1509  5 stars         Aluisio Melo
#
#                                                 comment comment_time helpful
# 0     Always making an effort to save and often succ...   2024-04-10
# 1     This has worked once for me, but I'm saving mo...   2024-04-10
# 2                                                  good   2024-04-10
# 3                                            VERY GOOD!   2024-04-10
# 4                                        almost 100 off   2024-04-10
# ...                                                 ...          ...     ...
# 1505                   Just saved 100 bucks! thank you!   2024-01-18
# 1506  The easiest $21 I ever saved. Go for it! Coupo...   2024-01-18
# 1507                                                      2024-01-18
# 1508                                                      2024-01-18
# 1509                     Exelente, economizei 40 reais.   2024-01-18
#
# [1510 rows x 5 columns]

# %%
output_data = parse_comments()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 54/54 [00:00<?, ?it/s]

# %%
output_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def fetchUrl(url,cookies=None):
    """
    Fetches content from a URL using a GET request with custom User-Agent and cookies.
    """
    # Ensure headers and cookies are dictionaries, if not provided, initialize as empty dicts
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    headers = {"User-Agent": user_agent}
    if cookies is None:
        cookies = {}
    
    # Perform the GET request
    response = requests.get(url, headers=headers, cookies=cookies)
    
    return response

def amazon_cookie_manage():
    """save cookie from https://moz.com/domain-analysis"""
    with open("config/amazon_cookie.json","r") as file:
        cookies = json.loads(file.read())
        cookies = cookies["cookies"]
        cookies_amazon = {cookie["name"]:cookie["value"] for cookie in cookies}
    return cookies_amazon

# %%
cookies = amazon_cookie_manage()
result = fetchUrl("https://www.amazon.com/Wordle-Party-Players-Official-Inspired/dp/B0B5B9CP17",cookies=cookies)

# %%
with open("amazon_test.html","w",encoding="utf-8") as file:
    file.write(result.text)

# %%
response.find_all("div",attrs={"id":"cm-cr-dp-review-list"})[0].text
# Out:
# "k. dorst5.0 out of 5 stars\nTaste amazing!\nReviewed in the United States on February 26, 2024Flavor Name: RaspberryVerified Purchase\nThis was highly recommended to me by my daughter who is deep into fitness and super healthy in general. It’s amazing all the benefits you get from taking this daily. I take a full tablespoon every morning on an empty stomach before having my coffee. I feel like it’s helping my skin and hair as well as helping to keep me healthy. Several coworkers are sick and I work side by side  them and yet I haven’t caught their sickness!! Can’t say 100% if it’s due to the sea moss but also can’t say that it’s not. None of my coworkers are taking sea moss, so yeah! I bought the raspberry one, it’s soooo good!! I love the taste!!! I will be ordering again soon!\nRead more\n21 people found this helpful\n\n\n              Helpful\n\n\nReport\nCaprice Caliendo5.0 out of 5 stars\nGreat taste\nReviewed in the United States on March 20, 2024Flavor Name: Apple CinnamonVerified Purchase\nI’ve been taking this product for about two weeks. I got the apple cinnamon and almost takes like an apple pie. I take a big tablespoon in the morning before breakfast. I do find it it gives me energy as well as curving my appetite. I don’t want to take any more cause I want the bottle to last once I get done I will order another one this time. I think I’m gonna try the raspberry.  I can’t wait to see and feel the results.\nRead more\n7 people found this helpful\n\n\n              Helpful\n\n\nReport\nSofia5.0 out of 5 stars\nGreat taste\nReviewed in the United States on March 31, 2024Flavor Name: Mango PineappleVerified Purchase\nThis product has been helping with energy and it tastes amazing. I was worried because i had heard that sea moss tasted bad. But after someone recommended this product i decided to try it. It honestly tastes like mango baby Gerber or apples sauce which i don’t mind at all!\nRead more\n2 people found this helpful\n\n\n              Helpful\n\n\nReport\nMercedes Garcia4.0 out of 5 stars\nTasted good\nReviewed in the United States on April 11, 2024Flavor Name: Lemon GingerVerified Purchase\nObviously the flavor is a preference but I thought it was absolutely delicious. I didn’t really know what to gauge to see if it made a difference in my health. I did notice that I was waking up and actually feeling well rested which isn’t a norm for me. It tasted great and I didn’t feel terrible after taking it daily. I can only assume that it was doing its thing and filling those missing gaps in my daily mineral intake but I’d buy it again. Overall, thumbs up.\nRead more\n\n\n\n              Helpful\n\n\nReport\nECT5.0 out of 5 stars\nSecond jar - best sea moss gel ever\nReviewed in the United States on January 23, 2024Flavor Name: Mango PineappleVerified Purchase\nI should have stuck with EverSmith Organics from the beginning. I loved the flavor, the texture. Everything about it I loved. Efficacy has been great as well I noticed a difference the first month I took it in my cycles. Far less cramping and peri-menopause symptoms.After I finished my EverSmith Organics jar, I got influenced into trying a different brand (same mango flavor with Ashwagandha but a larger jar, same price) thinking it would be the same quality. I’m here to tell you not all Irish sea moss gel is created equal.EverSmith Organics is FAR superior in flavor and texture. I struggled to finish the two jars (one was a freebie) I had from the other brand and rejoiced when they were finally gone. I’ll never stray again. EverSmith Organics is absolutely DELICIOUS, the texture is akin to applesauce and I will buy it every time. I only wish the jars were a bit larger.\nRead more\n28 people found this helpful\n\n\n              Helpful\n\n\nReport\nFrancesco Lamparell5.0 out of 5 stars\nEnergy boost!\nReviewed in the United States on February 10, 2024Flavor Name: Mixed BerryVerified Purchase\nI have tried a few different sea moss gel brands before finding EverS ...

# %%
def parse_page(path):
    with open(f"{path}","r",encoding="utf-8") as file:
        response = file.read()
    response = BeautifulSoup(response)

    title = response.find("span",attrs={"id":"productTitle"}).text.strip()
    rate = response.find("span",attrs={"id":"acrPopover"}).span.a.span.text.strip()
    rate_number = response.find("span",attrs={"id":"acrCustomerReviewText"}).text.strip()
    sold_number = response.find("span",attrs={"id":"social-proofing-faceout-title-tk_bought"}).span.text.strip()
    description = response.find("div",attrs={"id":"feature-bullets"}).ul.text
    rate_dist = [tr.text for tr in response.select("#cm_cr_dp_d_rating_histogram")[0].find_all("tr")]
    ai_comment = response.select("#product-summary")[0].text
    keyword_comments = response.select("#cr-product-insights-cards > div:nth-child(2) > div.a-section.a-spacing-mini._cr-product-insights_style_sentiment-section__6zKPq > div ")[0].find_all("span")
    keyword_comments = [span.text for span in keyword_comments]
    nav = " ".join([li.text.strip() for li in response.select("#wayfinding-breadcrumbs_feature_div > ul > li")])
    user_reviews = response.find_all("div",attrs={"id":"cm-cr-dp-review-list"})[0].text

    product_info = {
        "title": title,
        "rate": rate,
        "rate_number": rate_number,
        "sold_number": sold_number,
        "description": description,
        "rate_dist": rate_dist,
        "ai_comment": ai_comment,
        "keyword_comments": keyword_comments,
        "nav": nav,
        "user_reviews":user_reviews
    }

    return product_info

# %%
url_list = os.listdir("data/amazon_html/")
url_list
# Out:
# ['amazon_0.html',
#  'amazon_1.html',
#  'amazon_10.html',
#  'amazon_100.html',
#  'amazon_101.html',
#  'amazon_102.html',
#  'amazon_103.html',
#  'amazon_104.html',
#  'amazon_105.html',
#  'amazon_106.html',
#  'amazon_107.html',
#  'amazon_108.html',
#  'amazon_109.html',
#  'amazon_11.html',
#  'amazon_110.html',
#  'amazon_111.html',
#  'amazon_112.html',
#  'amazon_113.html',
#  'amazon_114.html',
#  'amazon_115.html',
#  'amazon_116.html',
#  'amazon_117.html',
#  'amazon_118.html',
#  'amazon_119.html',
#  'amazon_12.html',
#  'amazon_120.html',
#  'amazon_121.html',
#  'amazon_122.html',
#  'amazon_123.html',
#  'amazon_124.html',
#  'amazon_125.html',
#  'amazon_126.html',
#  'amazon_127.html',
#  'amazon_128.html',
#  'amazon_129.html',
#  'amazon_13.html',
#  'amazon_130.html',
#  'amazon_131.html',
#  'amazon_132.html',
#  'amazon_133.html',
#  'amazon_134.html',
#  'amazon_135.html',
#  'amazon_136.html',
#  'amazon_137.html',
#  'amazon_138.html',
#  'amazon_139.html',
#  'amazon_14.html',
#  'amazon_140.html',
#  'amazon_141.html',
#  'amazon_142.html',
#  'amazon_143.html',
#  'amazon_144.html',
#  'amazon_145.html',
#  'amazon_146.html',
#  'amazon_147.html',
#  'amazon_148.html',
#  'amazon_149.html',
#  'amazon_15.html',
#  'amazon_150.html',
#  'amazon_151.html',
#  'amazon_152.html',
#  'amazon_153.html',
#  'amazon_154.html',
#  'amazon_155.html',
#  'amazon_156.html',
#  'amazon_157.html',
#  'amazon_158.html',
#  'amazon_159.html',
#  'amazon_16.html',
#  'amazon_160.html',
#  'amazon_161.html',
#  'amazon_162.html',
#  'amazon_163.html',
#  'amazon_164.html',
#  'amazon_165.html',
#  'amazon_166.html',
#  'amazon_167.html',
#  'amazon_168.html',
#  'amazon_169.html',
#  'amazon_17.html',
#  'amazon_170.html',
#  'amazon_18.html',
#  'amazon_19.html',
#  'amazon_2.html',
#  'amazon_20.html',
#  'amazon_200.html',
#  'amazon_201.html',
#  'amazon_202.html',
#  'amazon_203.html',
#  'amazon_204.html',
#  'amazon_205.html',
#  'amazon_206.html',
#  'amazon_207.html',
#  'amazon_208.html',
#  'amazon_209.html',
#  'amazon_21.html',
#  'amazon_210.html',
#  'amazon_211.html',
#  'amazon_212.html',
#  'amazon_213.html',
#  'amazon_214.html',
#  'amazon_215.html',
#  'amazon_216.html',
#  'amazon_217.html',
#  'amazon_218.html',
#  'amazon_219.html',
#  'amazon_22.html',
#  'amazon_220.html',
#  'amazon_221.html',
#  'amazon_222.html',
#  'amazon_223.html',
#  'amazon_224.html',
#  'amazon_225.html',
#  'amazon_226.html',
#  'amazon_227.html',
#  'amazon_228.html',
#  'amazon_229.html',
#  'amazon_23.html',
#  'amazon_230.html',
#  'amazon_231.html',
#  'amazon_232.html',
#  'amazon_233.html',
#  'amazon_234.html',
#  'amazon_235.html',
#  'amazon_236.html',
#  'amazon_237.html',
#  'amazon_238.html',
#  'amazon_239.html',
#  'amazon_24.html',
#  'amazon_240.html',
#  'amazon_241.html',
#  'amazon_242.html',
#  'amazon_243.html',
#  'amazon_244.html',
#  'amazon_245.html',
#  'amazon_246.html',
#  'amazon_247.html',
#  'amazon_248.html',
#  'amazon_249.html',
#  'amazon_25.html',
#  'amazon_250.html',
#  'amazon_251.html',
#  'amazon_252.html',
#  'amazon_253.html',
#  'amazon_254.html',
#  'amazon_255.html',
#  'amazon_256.html',
#  'amazon_257.html',
#  'amazon_258.html',
#  'amazon_259.html',
#  'amazon_26.html',
#  'amazon_260.html',
#  'amazon_261.html',
#  'amazon_262.html',
#  'amazon_263.html',
#  'amazon_264.html',
#  'amazon_265.html',
#  'amazon_266.html',
#  'amazon_267.html',
#  'amazon_268.html',
#  'amazon_269.html',
#  'amazon_27.html',
#  'amazon_270.html',
#  'amazon_271.html',
#  'amazon_272.html',
#  'amazon_273.html',
#  'amazon_274.html',
#  'amazon_275.html',
#  'amazon_276.html',
#  'amazon_277.html',
#  'amazon_278.html',
#  'amazon_279.html',
#  'amazon_28.html',
#  'amazon_280.html',
#  'amazon_281.html',
#  'amazon_282.html',
#  'amazon_283.html',
#  'amazon_284.html',
#  'amazon_285.html',
#  'amazon_286.html',
#  'amazon_287.html',
#  'amazon_288.html',
#  'amazon_289.html',
#  'amazon_29.html',
#  'amazon_290.html',
#  'amazon_291.html',
#  'amazon_292.html',
#  'amazon_293.html',
#  'amazon_294.html',
#  'amazon_295.html',
#  'amazon_296.html',
#  'amazon_297.html',
#  'amazon_298.html',
#  'amazon_299.html',
#  'amazon_3.html',
#  'amazon_30.html',
#  'amazon_300.html',
#  'amazon_301.html',
#  'amazon_302.html',
#  'amazon_303.html',
#  'amazon_304.html',
#  'amazon_305.html',
#  'amazon_306.html',
#  'amazon_307.html',
#  'amazon_308.html',
#  'amazon_309.html',
#  'amazon_31.html',
#  'amazon_310.html',
#  'amazon_311.html',
#  'amazon_312.html',
#  'amazon_313.html',
#  'amazon_314.html',
#  'amazon_315.html',
#  'amazon_316.html',
#  'amazon_317.html',
#  'amazon_318.html',
#  'amazon_319.html',
#  'amazon_32.html',
#  'amazon_320.html',
#  'amazon_321.html',
#  'amazon_322.html',
#  'amazon_323.html',
#  'amazon_324.html',
#  'amazon_325.html',
#  'amazon_326.html',
#  'amazon_327.html',
#  'amazon_328.html',
#  'amazon_329.html',
#  'amazon_33.html',
#  'amazon_330.html',
#  'amazon_331.html',
#  'amazon_332.html',
#  'amazon_333.html',
#  'amazon_334.html',
#  'amazon_335.html',
#  'amazon_336.html',
#  'amazon_337.html',
#  'amazon_338.html',
#  'amazon_339.html',
#  'amazon_34.html',
#  'amazon_340.html',
#  'amazon_341.html',
#  'amazon_342.html',
#  'amazon_343.html',
#  'amazon_344.html',
#  'amazon_345.html',
#  'amazon_346.html',
#  'amazon_347.html',
#  'amazon_348.html',
#  'amazon_349.html',
#  'amazon_35.html',
#  'amazon_350.html',
#  'amazon_351.html',
#  'amazon_352.html',
#  'amazon_353.html',
#  'amazon_354.html',
#  'amazon_355.html',
#  'amazon_356.html',
#  'amazon_357.html',
#  'amazon_358.html',
#  'amazon_359.html',
#  'amazon_36.html',
#  'amazon_360.html',
#  'amazon_361.html',
#  'amazon_362.html',
#  'amazon_363.html',
#  'amazon_364.html',
#  'amazon_365.html',
#  'amazon_366.html',
#  'amazon_367.html',
#  'amazon_368.html',
#  'amazon_369.html',
#  'amazon_37.html',
#  'amazon_370.html',
#  'amazon_371.html',
#  'amazon_372.html',
#  'amazon_373.html',
#  'amazon_374.html',
#  'amazon_375.html',
#  'amazon_376.html',
#  'amazon_377.html',
#  'amazon_378.html',
#  'amazon_379.html',
#  'amazon_38.html',
#  'amazon_380.html',
#  'amazon_381.html',
#  'amazon_382.html',
#  'amazon_383.html',
#  'amazon_384.html',
#  'amazon_385.html',
#  'amazon_386.html',
#  'amazon_387.html',
#  'amazon_388.html',
#  'amazon_389.html',
#  'amazon_39.html',
#  'amazon_390.html',
#  'amazon_4.html',
#  'amazon_40.html',
#  'amazon_41.html',
#  'amazon_42.html',
#  'amazon_43.html',
#  'amazon_44.html',
#  'amazon_45.html',
#  'amazon_46.html',
#  'amazon_47.html',
#  'amazon_48.html',
#  'amazon_49.html',
#  'amazon_5.html',
#  'amazon_50.html',
#  'amazon_51.html',
#  'amazon_52.html',
#  'amazon_53.html',
#  'amazon_54.html',
#  'amazon_55.html',
#  'amazon_56.html',
#  'amazon_57.html',
#  'amazon_58.html',
#  'amazon_59.html',
#  'amazon_6.html',
#  'amazon_60.html',
#  'amazon_61.html',
#  'amazon_62.html',
#  'amazon_63.html',
#  'amazon_64.html',
#  'amazon_65.html',
#  'amazon_66.html',
#  'amazon_67.html',
#  'amazon_68.html',
#  'amazon_69.html',
#  'amazon_7.html',
#  'amazon_70.html',
#  'amazon_71.html',
#  'amazon_72.html',
#  'amazon_73.html',
#  'amazon_74.html',
#  'amazon_75.html',
#  'amazon_76.html',
#  'amazon_77.html',
#  'amazon_78.html',
#  'amazon_79.html',
#  'amazon_8.html',
#  'amazon_80.html',
#  'amazon_81.html',
#  'amazon_82.html',
#  'amazon_83.html',
#  'amazon_84.html',
#  'amazon_85.html',
#  'amazon_86.html',
#  'amazon_87.html',
#  'amazon_88.html',
#  'amazon_89.html',
#  'amazon_9.html',
#  'amazon_90.html',
#  'amazon_91.html',
#  'amazon_92.html',
#  'amazon_93.html',
#  'amazon_94.html',
#  'amazon_95.html',
#  'amazon_96.html',
#  'amazon_97.html',
#  'amazon_98.html',
#  'amazon_99.html']

# %%
output = []
for url in tqdm(url_list):
    try:
        result = parse_page(f"data/amazon_html/{url}")
        output.append(result)
    except:
        continue
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 362/362 [01:40<00:00,  3.61it/s]

# %%
pd.DataFrame(output)
# Out:
#                                                  title rate      rate_number  \
# 0    Amazon Fire TV Stick, HD, sharp picture qualit...  4.7  462,719 ratings
# 1    Pure Instinct Roll-On - The Original Pheromone...  3.9   81,031 ratings
# 2    Quest 2 — Advanced All-In-One Virtual Reality ...  4.7   71,784 ratings
# 3    Google Pixel 6a - 5G Android Phone - Unlocked ...  4.3    4,762 ratings
# 4    WalkingPad Folding Treadmill, Ultra Slim Folda...  3.9      803 ratings
# ..                                                 ...  ...              ...
# 98   Amazon Basics High-Speed HDMI Cable For Televi...  4.7  533,087 ratings
# 99   Hero Cosmetics Mighty Patch™ Original Patch - ...  4.6  142,363 ratings
# 100  Nugenix Total-T, Free and Total Testosterone B...  4.1   15,820 ratings
# 101  URO Vaginal Probiotics for Women pH Balance wi...  4.3      340 ratings
# 102  Samyang Buldak Chicken Stir Fried Ramen Korean...  4.4    3,932 ratings
#
#                     sold_number  \
# 0     10K+ bought in past month
# 1     10K+ bought in past month
# 2     30K+ bought in past month
# 3     200+ bought in past month
# 4     500+ bought in past month
# ..                          ...
# 98    10K+ bought in past month
# 99   100K+ bought in past month
# 100   10K+ bought in past month
# 101  100K+ bought in past month
# 102    1K+ bought in past month
#
#                                            description  \
# 0      50% more powerful than the previous generati...
# 1      More than 20 years ago, Pure Instinct change...
# 2      Experience total immersion with 3D positiona...
# 3      Google Pixel 6a adapts to you; it’s super fa...
# 4      Ultra Slim Foldable Running Board For Easy S...
# ..                                                 ...
# 98     IN THE BOX: HDMI cable (A Male to A Male) fo...
# 99     🏆 The Original Award-Winning Acne Patch: Mig...
# 100    Scientifically formulated, our new-and-impro...
# 101    Promotes Vaginal Health: URO Probiotic for w...
# 102    1 x Buldak Original / 1 x Carbo / 1 x Cheese...
#
#                                              rate_dist  \
# 0    [5 star82%, 4 star11%, 3 star3%, 2 star1%, 1 s...
# 1    [5 star52%, 4 star13%, 3 star14%, 2 star8%, 1 ...
# 2    [5 star84%, 4 star9%, 3 star3%, 2 star1%, 1 st...
# 3    [5 star67%, 4 star15%, 3 star5%, 2 star4%, 1 s...
# 4    [5 star57%, 4 star16%, 3 star6%, 2 star6%, 1 s...
# ..                                                 ...
# 98   [5 star82%, 4 star12%, 3 star4%, 2 star1%, 1 s...
# 99   [5 star76%, 4 star12%, 3 star7%, 2 star2%, 1 s...
# 100  [5 star59%, 4 star15%, 3 star12%, 2 star5%, 1 ...
# 101  [5 star74%, 4 star8%, 3 star3%, 2 star3%, 1 st...
# 102  [5 star72%, 4 star13%, 3 star7%, 2 star3%, 1 s...
#
#                                             ai_comment  \
# 0    Customers sayCustomers like the performance an...
# 1    Customers sayCustomers like the portability of...
# 2    Customers sayCustomers like the ease of setup ...
# 3    Customers sayCustomers like the value of the c...
# 4    Customers sayCustomers like the ease of foldin...
# ..                                                 ...
# 98   Customers sayCustomers like the quality, value...
# 99   Customers sayCustomers like the quality, visib...
# 100  Customers sayCustomers like the energy, qualit...
# 101  Customers sayCustomers like the vitamins, perf...
# 102  Customers sayCustomers like the quality of the...
#
#                                       keyword_comments  \
# 0                  [Performance, Ease of use, Quality]
# 1    [Appearance, Portability, Ease of application,...
# 2    [Quality, Entertainment value, Ease of setup, ...
# 3    [Value, Photos, Quality, Battery life, Chargin...
# 4    [Ease of folding, Performance, Ease of use, Qu...
# ..                                                 ...
# 98   [Performance, Quality, Value, Fit, Picture qua...
# 99   [Performance, Effect on skin, Quality, Sensiti...
# 100  [Energy, Quality, Effects, Performance, Sleep ...
# 101  [Performance, Smell, Vitamins, Health benefits...
# 102  [Quality, Ease of making, Taste, Temperature, ...
#
#                                                    nav  \
# 0
# 1    Beauty & Personal Care › Fragrance › Men's › C...
# 2    Video Games › Virtual Reality › Standalone Har...
# 3              Cell Phones & Accessories › Cell Phones
# 4    Sports & Outdoors › Exercise & Fitness › Cardi...
# ..                                                 ...
# 98   Electronics › Television & Video › Accessories...
# 99   Beauty & Personal Care › Skin Care › Face › Tr...
# 100  Health & Household › Diet & Sports Nutrition ›...
# 101  Health & Household › Health Care › Women's Hea...
# 102  Grocery & Gourmet Food › Pantry Staples › Soup...
#
#                                           user_reviews
# 0    CARLOS PINEDA5.0 out of 5 stars\nAwesome quali...
# 1    Natalia5.0 out of 5 stars\nWorks! Just not how...
# 2    Yaura5.0 out of 5 stars\nAmazing Overall\nRevi...
# 3    Nurse Bill5.0 out of 5 stars\nSolid as a rock\...
# 4    Amazon Customer5.0 out of 5 stars\nWalking whi...
# ..                                                 ...
# 98   carla5.0 out of 5 stars\nYear-Long Reliability...
# 99   Ana Maria5.0 out of 5 stars\nMaybe not the bes...
# 100  Odizie Ajike5.0 out of 5 stars\nUOUR PRODUCT\n...
# 101  A. Williams5.0 out of 5 stars\nI’ve noticed a ...
# 102  Gavin Whittington5.0 out of 5 stars\nTaste gre...
#
# [103 rows x 10 columns]

# %%
def sleep_time(base,random=1):
    random_time = base + np.random.randint(10000,99999)/(10**5)
    time.sleep(random_time)

# %%
pd.DataFrame(output).to_clipboard()

# %%
input_data = pd.read_csv("data/amazon_url_test.csv")
url_list = input_data["URL"].to_list()

# %%
result = fetchUrl("https://www.amazon.com/Wordle-Party-Players-Official-Inspired/dp/B0B5B9CP17",cookies=cookies)

# %%
i = 1500
for url in tqdm(url_list[1500:2000]):
 
    url = url+"?language=en_US"
    sleep_time(1)
    cookies = amazon_cookie_manage()
    response = fetchUrl(f"{url}",cookies=cookies)
    with open(f"data/amazon_html/amazon_{i}.html","w",encoding="utf-8") as file:
        file.write(response.text)
    sleep_time(3)
    i += 1
# Out:
#   5%|███▊                                                                           | 24/500 [03:24<1:06:31,  8.39s/it]
